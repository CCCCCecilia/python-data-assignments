# %%
# !pip install jieba
# !pip install seaborn
# !pip install pyecharts
# !pip install pillow
# !pip install wordcloud
# !pip install numpy
# !pip install scipy
# !pip install imageio
# !pip install pyecharts_snapshot
# !pip install Ipython

# %%
import jieba
import pyecharts
import matplotlib
import wordcloud
import numpy as np
import pandas as pd
import seaborn as sns
from PIL import Image
from pyecharts import Bar,configure,online
from imageio import imread 
import matplotlib.pyplot as plt 
from IPython.display import IFrame 
from wordcloud import WordCloud, ImageColorGenerator

# %%
df = pd.read_csv('jay.csv')

# %%
#定义切分歌词函数，去stopwords
def cut_lyrics(df):
    all_lyrics = df.歌词.tolist()
    one_lyrics = ''
    for lyrics in all_lyrics :
        lyrics_list =  lyrics.replace("\t","").split('\n\n')
        for i in range(len(lyrics_list)-1):
            one_lyrics += lyrics_list[i].replace("\n","").lower()
    #print(one_lyrics)
    words = jieba.cut(one_lyrics)
    #set stopwords
    filepath = 'stopwords.txt'
    stopwords = [line.strip() for line in open(filepath, 'r', encoding='utf-8').readlines()]   
    stopwords.extend(['oh','hey','go','ya','我会','不到','真的','想要','混音','不用','录音师'])
    #remove stopwords
    processed_word_list = [] 
    for word in words:
        if word not in stopwords and len(word)>1: #remove single word
            processed_word_list.append(word)
    return processed_word_list

# %% [markdown]
# ## World Clouds

# %%
#定义词云函数
def word_cloud(processed_word_list, rank=100):
    word_count100 = pd.Series(processed_word_list).value_counts().sort_values(ascending=False)[:rank]
    word_count100_dict = word_count100.to_dict()
    result = " ".join(word_count100_dict)  
    image = imread("jay.jpg")
    wc = WordCloud(
        font_path="simhei.ttf",
        background_color='orange',   
        max_font_size=35,   #最大字号
        mask=image 
    )
    wc.generate(result)
    image_color = ImageColorGenerator(image)
    wc.recolor(color_func=image_color)
    wc.to_file("jay_worldcloud.png")
    plt.figure("jay") 
    plt.figure(figsize=(7,7))
    plt.imshow(wc)
    plt.axis("off")
    plt.show()
    
processed_word_list = cut_lyrics(df)
word_cloud(processed_word_list)
# Out:
# Building prefix dict from the default dictionary ...
# DEBUG:jieba:Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/9y/hdd1pgmn3kb7bc7tzlxh0y5w0000gn/T/jieba.cache
# DEBUG:jieba:Loading model from cache /var/folders/9y/hdd1pgmn3kb7bc7tzlxh0y5w0000gn/T/jieba.cache
# Loading model cost 0.796 seconds.
# DEBUG:jieba:Loading model cost 0.796 seconds.
# Prefix dict has been built succesfully.
# DEBUG:jieba:Prefix dict has been built succesfully.

# %% [markdown]
# ## 1.What is the most frequent word in Jay Chou's lyrics?
# In this chart, I show the most frequently used words in Jay Chou's lyrics. They are: "微笑”，“離開”，“愛情”，“世界”，“回憶”，“憧憬”，“感覺”，“公公”，“時間”，“音樂”，“記得”，“永遠”，“喜歡”，“故事”，“沈默”. And from these words we can perceive his musical theme and tone.
# But this word  "公公" is an exception, it only appears in one song name “公公偏頭痛”.

# %%
def word_count_bar(inputs):
    fig = plt.figure(figsize=(12,6))  
    x =inputs.index.tolist()  
    y = inputs.values.tolist() 
    sns.barplot(x, y, palette="Paired_r")  
    #sns theme
    plt.title('word frequency top 15')  
    plt.ylabel('count')  
    sns.despine(bottom=True)  
    plt.savefig('jay_word_count_bar.png',dpi=400)
    plt.show() 
word_count = pd.Series(processed_word_list).value_counts().sort_values(ascending=False)[:15]
word_count_bar(word_count)

# %% [markdown]
# ## 2.Who is the most commonly used lyricist ?
# This chart shows who are writing for Jay Chou's songs. We all know that Fang Wenshan is the major lyricist of Jay Chou's songs. Through data we proved this and we can also see that Jay Chou himself also writed many lyrics.

# %%
def show_top_lyrist(df, rank = 10):
    plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
    plt.rcParams['axes.unicode_minus']=False #用来正常显示负号

    lyricist_counts=df['作词'].value_counts()[:rank].sort_values(ascending=False) #sort values
    作词 = pd.DataFrame(lyricist_counts)
    fig = plt.figure(figsize=(14,7)) #adjust size
    plt.bar(作词.index, 作词.作词, color = '#EE9A49')
    plt.title('top'+str(rank)+'lyricist') #plot title and label name
    plt.xlabel('作词')
    plt.ylabel('counts')
    plt.savefig('jay_top_lyrist.png',dpi=400)
    plt.show()
show_top_lyrist(df)

# %% [markdown]
# ## 3.The popularity of Jay Chou's albums.
# I scraped the number of sharing and comments of Jay Chou's album on [Xiami](https://www.xiami.com/artist/iim17edb?spm=0.0.0.0.vCdvep), and  use it as parameters to analyze the popularity of Jay Chou's different albums.
# In this chart, we can see that the album "范特西" is the top one.

# %%
pd_df1 = df.groupby(['专辑名'])['分享数'].mean().reset_index().sort_values("分享数",ascending=False)
pd_df2 = df.groupby(['专辑名'])['评论数'].mean().reset_index().sort_values("评论数",ascending=False)
attr = pd_df1.专辑名
v1 = pd_df1.分享数
v2 = pd_df2.评论数
bar = Bar("从评论数和分享数看周杰伦专辑")
bar.add("分享数", attr, v1)
bar.add("评论数", attr, v2)
bar.render('jay_sharing.html')
from IPython.display import IFrame
IFrame('jay_sharing.html', width=800, height=400)
# Out:
#         <iframe
#             width="800"
#             height="400"
#             src="jay_sharing.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
